# %%
aa=open("encoded_family_relevant.txt")

# %%
wf=open("relevant_fasta.txt","w")
cc=1
for a in aa:
    a=a.rstrip()
    a=a.split("\t")
    print(a)
    fam=a[0]
    print(fam)
    wf.write(">reference_"+fam+"_"+str(cc))
    wf.write("\n")
    wf.write(a[1])
    wf.write("\n")
    cc+=1
wf.close()
# Out:
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Worm', '...']
# Worm
# ['Trojan', '...']
# Trojan
# ['Trojan', '...']
# Trojan
# ['Trojan', '...']
# Trojan
# ['Trojan', '...']
# Trojan
# ...
